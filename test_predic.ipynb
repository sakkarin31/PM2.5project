# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import pycaret
from pycaret.classification import *
from pycaret.datasets import get_data

# %%
data_pm = pd.read_csv('train2.csv')
data_pm
# Out:
#              DATETIMEDATA  PM25         O3  WS  TEMP    RH     WD
# 0     2024-01-01 00:00:00  16.5  16.000000   1  27.0  79.0  115.0
# 1     2024-01-01 01:00:00  33.6  11.479814   1  27.0  82.0   97.0
# 2     2024-01-01 02:00:00  34.2  11.479814   1  26.0  84.0   96.0
# 3     2024-01-01 03:00:00  20.1  11.479814   1  26.0  82.0  108.0
# 4     2024-01-01 04:00:00  16.5   1.000000   1  27.0  79.0  106.0
# ...                   ...   ...        ...  ..   ...   ...    ...
# 1531  2024-03-04 19:00:00  17.5  27.000000   2  29.0  70.0  116.0
# 1532  2024-03-04 20:00:00  23.9  27.000000   2  29.0  73.0  115.0
# 1533  2024-03-04 21:00:00  20.4  29.000000   2  28.0  75.0  113.0
# 1534  2024-03-04 22:00:00  19.5  24.000000   1  28.0  77.0  110.0
# 1535  2024-03-04 23:00:00  20.1  13.208916   1  28.0  77.0  110.0
#
# [1536 rows x 7 columns]

# %%
from pycaret.regression import *
clf1 = setup(data_pm, target='PM25', session_id = 123)
# Out:
# <style type="text/css">
# #T_d77c0_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d77c0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d77c0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d77c0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d77c0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d77c0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d77c0_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d77c0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d77c0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d77c0_row1_col1" class="data row1 col1" >PM25</td>
#     </tr>
#     <tr>
#       <th id="T_d77c0_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_fe4a0 th {
#   text-align: left;
# }
# ...

# %%
en = create_model('en')
# Out:
# <style type="text/css">
# #T_f0c81_row10_col0, #T_f0c81_row10_col1, #T_f0c81_row10_col2, #T_f0c81_row10_col3, #T_f0c81_row10_col4, #T_f0c81_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f0c81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f0c81_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f0c81_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f0c81_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f0c81_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f0c81_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f0c81_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_model = tune_model(en)
# Out:
# <style type="text/css">
# #T_c65b2_row10_col0, #T_c65b2_row10_col1, #T_c65b2_row10_col2, #T_c65b2_row10_col3, #T_c65b2_row10_col4, #T_c65b2_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_c65b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c65b2_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c65b2_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c65b2_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c65b2_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c65b2_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_c65b2_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
ensem = ensemble_model(en , n_estimators=50)
# Out:
# <style type="text/css">
# #T_6e68a_row10_col0, #T_6e68a_row10_col1, #T_6e68a_row10_col2, #T_6e68a_row10_col3, #T_6e68a_row10_col4, #T_6e68a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_6e68a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e68a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6e68a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6e68a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6e68a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6e68a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_6e68a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
test = pd.read_csv('test_to_predict.csv')
predict_model(bagged,data=test)
